# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\kakka\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: numpy in c:\users\kakka\anaconda3\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\kakka\anaconda3\lib\site-packages (from xgboost) (1.11.1)

# %%
from xgboost import XGBClassifier

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\kakka\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\kakka\anaconda3\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\kakka\anaconda3\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\kakka\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kakka\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lime
# Out:
# Requirement already satisfied: lime in c:\users\kakka\anaconda3\lib\site-packages (0.2.0.1)
# Requirement already satisfied: matplotlib in c:\users\kakka\anaconda3\lib\site-packages (from lime) (3.7.2)
# Requirement already satisfied: numpy in c:\users\kakka\anaconda3\lib\site-packages (from lime) (1.24.3)
# Requirement already satisfied: scipy in c:\users\kakka\anaconda3\lib\site-packages (from lime) (1.11.1)
# Requirement already satisfied: tqdm in c:\users\kakka\anaconda3\lib\site-packages (from lime) (4.65.0)
# Requirement already satisfied: scikit-learn>=0.18 in c:\users\kakka\anaconda3\lib\site-packages (from lime) (1.3.0)
# Requirement already satisfied: scikit-image>=0.12 in c:\users\kakka\anaconda3\lib\site-packages (from lime) (0.20.0)
# Requirement already satisfied: networkx>=2.8 in c:\users\kakka\anaconda3\lib\site-packages (from scikit-image>=0.12->lime) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\kakka\anaconda3\lib\site-packages (from scikit-image>=0.12->lime) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\kakka\anaconda3\lib\site-packages (from scikit-image>=0.12->lime) (2.26.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\kakka\anaconda3\lib\site-packages (from scikit-image>=0.12->lime) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\kakka\anaconda3\lib\site-packages (from scikit-image>=0.12->lime) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\kakka\anaconda3\lib\site-packages (from scikit-image>=0.12->lime) (23.1)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\kakka\anaconda3\lib\site-packages (from scikit-image>=0.12->lime) (0.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\kakka\anaconda3\lib\site-packages (from scikit-learn>=0.18->lime) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kakka\anaconda3\lib\site-packages (from scikit-learn>=0.18->lime) (2.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kakka\anaconda3\lib\site-packages (from matplotlib->lime) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\kakka\anaconda3\lib\site-packages (from matplotlib->lime) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kakka\anaconda3\lib\site-packages (from matplotlib->lime) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kakka\anaconda3\lib\site-packages (from matplotlib->lime) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\kakka\anaconda3\lib\site-packages (from matplotlib->lime) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kakka\anaconda3\lib\site-packages (from matplotlib->lime) (2.8.2)
# Requirement already satisfied: colorama in c:\users\kakka\anaconda3\lib\site-packages (from tqdm->lime) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\kakka\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->lime) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import LogisticRegression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression

import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.metrics import plot_confusion_matrix
import matplotlib.pyplot as plt

plot_confusion_matrix(model, xtest, ytest)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 from sklearn.metrics import plot_confusion_matrix
#       2 import matplotlib.pyplot as plt
#       4 plot_confusion_matrix(model, xtest, ytest)
#
# ImportError: cannot import name 'plot_confusion_matrix' from 'sklearn.metrics' (C:\Users\kakka\anaconda3\Lib\site-packages\sklearn\metrics\__init__.py)

# %%
df = pd.read_csv('wine quality.csv')
print(df.head())
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
df.dtypes
# Out:
# type                     object
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.describe().T
# Out:
#                        count        mean        std      min       25%  \
# fixed acidity         6487.0    7.216579   1.296750  3.80000   6.40000
# volatile acidity      6489.0    0.339691   0.164649  0.08000   0.23000
# citric acid           6494.0    0.318722   0.145265  0.00000   0.25000
# residual sugar        6495.0    5.444326   4.758125  0.60000   1.80000
# chlorides             6495.0    0.056042   0.035036  0.00900   0.03800
# free sulfur dioxide   6497.0   30.525319  17.749400  1.00000  17.00000
# total sulfur dioxide  6497.0  115.744574  56.521855  6.00000  77.00000
# density               6497.0    0.994697   0.002999  0.98711   0.99234
# pH                    6488.0    3.218395   0.160748  2.72000   3.11000
# sulphates             6493.0    0.531215   0.148814  0.22000   0.43000
# alcohol               6497.0   10.491801   1.192712  8.00000   9.50000
# quality               6497.0    5.818378   0.873255  3.00000   5.00000
#
#                             50%        75%        max
# fixed acidity           7.00000    7.70000   15.90000
# volatile acidity        0.29000    0.40000    1.58000
# citric acid             0.31000    0.39000    1.66000
# residual sugar          3.00000    8.10000   65.80000
# chlorides               0.04700    0.06500    0.61100
# free sulfur dioxide    29.00000   41.00000  289.00000
# total sulfur dioxide  118.00000  156.00000  440.00000
# density                 0.99489    0.99699    1.03898
# pH                      3.21000    3.32000    4.01000
# sulphates               0.51000    0.60000    2.00000
# alcohol                10.30000   11.30000   14.90000
# quality                 6.00000    6.00000    9.00000

# %%
df.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
numeric_df = df.select_dtypes(include='number')

# %%
df.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
for col in df.columns:
    if df[col].isnull().sum() > 0:
	    df[col] = df[col].fillna(df[col].mean())

df.isnull().sum().sum()
# Out:
# 0

# %%
df.hist(bins=20, figsize=(10, 10))
plt.show()

# %%
plt.bar(df['quality'], df['alcohol'])
plt.xlabel('quality')
plt.ylabel('alcohol')
plt.show()

# %%
non_numeric_columns = df.select_dtypes(exclude='number').columns
print("Non-numeric columns:", non_numeric_columns)
# Out:
# Non-numeric columns: Index([], dtype='object')

# %%
# ploting heatmap
plt.figure(figsize=[12,12],facecolor='yellow')
sb.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df = df.drop('total sulfur dioxide', axis=1)

# %% [markdown]
# MODEL DEVELOPMENT

# %%
df['best quality'] = [1 if x > 5 else 0 for x in df.quality]

# %%
df.replace({'white': 1, 'red': 0}, inplace=True)

# %%
features = df.drop(['quality', 'best quality'], axis=1)
target = df['best quality']

xtrain, xtest, ytrain, ytest = train_test_split(
	features, target, test_size=0.2, random_state=40)

xtrain.shape, xtest.shape
# Out:
# ((5197, 11), (1300, 11))

# %% [markdown]
# NORMALISING THE DATA

# %%
norm = MinMaxScaler()
xtrain = norm.fit_transform(xtrain)
xtest = norm.transform(xtest)

# %%
models = [LogisticRegression(), XGBClassifier(),  SVC(kernel='rbf')]

for i in range(3):
    models[i].fit(xtrain, ytrain)

print(f'{models[i]} : ')
print('Training Accuracy : ', metrics.roc_auc_score(ytrain, models[i].predict(xtrain)))
print('Validation Accuracy : ', metrics.roc_auc_score(
ytest, models[i].predict(xtest)))
print()
# Out:
# SVC() :
# Training Accuracy :  0.7069199304892986
# Validation Accuracy :  0.695796426272719

# %% [markdown]
# MODEL EVALUATION

# %%
metrics.plot_confusion_matrix(models[1], xtest, ytest)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 metrics.plot_confusion_matrix(models[1], xtest, ytest)
#       2 plt.show()
#
# AttributeError: module 'sklearn.metrics' has no attribute 'plot_confusion_matrix'
